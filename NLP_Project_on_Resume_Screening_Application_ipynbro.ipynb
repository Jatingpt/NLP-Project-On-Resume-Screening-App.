# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatingpt/NLP-Project-On-Resume-Screening-App./blob/main/NLP_Project_on_Resume_Screening_Application_ipynbro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Problem Statement.**
# ##**Companies often receive thousands of resumes for each job posting and employ dedicated screening officers to screen qualified candidates.**
#
# ##**Hiring the right talent is a challenge for all businesses. This challenge is magnified by the high volume of applicants if the business is labour-intensive, growing, and facing high attrition rates.**
#
# ##**IT departments are short of growing markets. In a typical service organization, professionals with a variety of technical skills and business domain expertise are hired and assigned to projects to resolve customer issues. This task of selecting the best talent among many others is known as Resume Screening.**

# %% [markdown]
# ##**Approach that is used to build this project.**
#
#
# * The approach we have used in this project is defined in the given format-
#
# ##1) **Loading our data** : In this section we just loaded our dataset in colab notebook and read the csv file.
#
# ##2) **Data Cleaning-** :
#
# **Punctuation**: Remove or preserve punctuation depending on the task (e.g., sentiment analysis might retain exclamation marks).
#
# **Special characters**: Remove symbols like @, #, $, etc., unless they have significance (e.g., hashtags in social media analysis).
#
# **HTML tags**: Strip out HTML or XML tags using libraries like BeautifulSoup for web-scraped data.
#
# **Stop words**: Remove common words like "and," "the," "is," etc., that don't carry much semantic weight unless needed for the task.
#
# ##**3) Data Preprocessing**-
# **Tokenization**
#
# Split the text into smaller units like words or sentences for further processing. Common tokenization methods:
#
# **Lemmatization and Stemming**
#
# Lemmatization: Convert words to their base or dictionary form (e.g., running → run).
# Stemming: Reduce words to their root form (e.g., running → run). Stemming is more aggressive and may lose linguistic meaning.
#
# ##4)**Text Vectorization**
#
# **Label encoding:**  Label encoding is a technique used to convert categorical data (labels) into numerical values, making it suitable for machine learning models.
#
# **TF-IDF (Term Frequency-Inverse Document Frequency)**: Assign weights to words based on their importance.
#
# 4) **Analysis and Visualization** : In this section we have tried to explore all variables which can play an important role for the analysis. In the next parts we have tried to explore the effect of one over the other. In the next part we tried to answers our hypothetical

# %% [markdown]
# ## **Python Libraries we used:**
#
# * **Numpy**
#
# * **Pandas**
#
# * **Seaborn**
#
# * **Matplotlib**
#
# * **Sckitlearn**
#
# * **SpaCy**

# %%
#Importing all the libraries.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import spacy
import sklearn

# %%
#Connecting this project with the google drive.
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
#Importing the data.
file_path = "/content/UpdatedResumeDataSet.csv"
df = pd.read_csv(file_path)
df
# Out:
#          Category                                             Resume
# 0    Data Science  Skills * Programming Languages: Python (pandas...
# 1    Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2    Data Science  Areas of Interest Deep Learning, Control Syste...
# 3    Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4    Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..            ...                                                ...
# 957       Testing  Computer Skills: â¢ Proficient in MS office (...
# 958       Testing  â Willingness to accept the challenges. â ...
# 959       Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 960       Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 961       Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
# [962 rows x 2 columns]

# %%
df.info()  #As the data has total 962 entries and 2 number of columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  962 non-null    object
#  1   Resume    962 non-null    object
# dtypes: object(2)
# memory usage: 15.2+ KB

# %%
#Checking the columns
df.columns
# Out:
# Index(['Category', 'Resume'], dtype='object')

# %%
df.head(2)
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...

# %% [markdown]
# As our data has two number of columns
#
#
# 1.   **Category**- The persons profile
# 2.   **Resume**- Resume of the candidate

# %%
#Null values

df.isnull().sum()        #There are no null values present in this data.
# Out:
# Category    0
# Resume      0
# dtype: int64

# %%
#All categories

df["Category"].unique()
# Out:
# array(['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing',
#        'Mechanical Engineer', 'Sales', 'Health and fitness',
#        'Civil Engineer', 'Java Developer', 'Business Analyst',
#        'SAP Developer', 'Automation Testing', 'Electrical Engineering',
#        'Operations Manager', 'Python Developer', 'DevOps Engineer',
#        'Network Security Engineer', 'PMO', 'Database', 'Hadoop',
#        'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing'],
#       dtype=object)

# %%
#Number of categories in each profile.

df["Category"].value_counts()
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Blockchain                   40
# ETL Developer                40
# Operations Manager           40
# Data Science                 40
# Sales                        40
# Mechanical Engineer          40
# Arts                         36
# Database                     33
# Electrical Engineering       30
# Health and fitness           30
# PMO                          30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# SAP Developer                24
# Civil Engineer               24
# Advocate                     20
# Name: count, dtype: int64

# %%
#Graphical representation of each category.
plt.figure(figsize = (10,8))
sns.countplot(df["Category"], color = "lightblue")
plt.title("Category Distribution")
plt.xlabel("Number of Resume")
plt.ylabel("Category")
plt.show()

# %%
print(df["Category"][0])
print()
print(df["Resume"][0])
# Out:
# Data Science
#
# Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details
#
# Data Science Assurance Associate
#
# Data Science Assurance Associate - Ernst & Young LLP
# Skill Details
# JAVASCRIPT- Exprience - 24 months
# jQuery- Exprience - 24 months
# Python- Exprience - 24 monthsCompany Details
# company - Ernst & Young LLP
# ...

# %% [markdown]
# ##**Creating a function to clean all the unnecessary words, characters and punctuations.**

# %%
#first importing the regular expression.

import re

def CleanResume(txt):
  Cleantext = re.sub("http\S+\s", " ", txt)  #Removing the urls which contains http along with the whole link attached with http, and replacing it with blank space.

  Cleantext = re.sub("@\s+", " ", Cleantext)  #removing the words which contains @ and replacing with space and now the new cleaned texts are stored in this variable

  Cleantext = re.sub("#\s+", " ", Cleantext)  #removing '#' and replacing with space also stored in Cleantext,

  Cleantext = re.sub("RT|cc", " ", Cleantext) #Some words contains RR|cc in the resume so we need to clean this too.

  Cleantext = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', Cleantext)  #To clean all the special characters available in the
                                                                                                  #resume with the help of escape function

  Cleantext = re.sub(r'[^\x00-\x7f]', ' ', Cleantext) #removing other unneccesary syntax that is present in the resume.

  Cleantext = re.sub(r'\s+', ' ', Cleantext)  # Remove extra spaces

  Cleantext = Cleantext.lower()  # Convert to lowercase

  return Cleantext

# %%
#Checking the function whether it is working properly or we need to improve.

CleanResume("My problem is very --## big and i @@# have to solve... it") #as we can see that our function is working properly
# Out:
# 'my problem is very big and i have to solve it'

# %%
#Filtering the resume with special characters and other unnecessary things by using lambda function.

df["Resume"] = df["Resume"].apply(lambda x: CleanResume(x))

# %%
df["Resume"][0]
# Out:
# 'skills programming languages python pandas numpy scipy scikit learn matplotlib sql java javascript jquery machine learning regression svm na ve bayes knn random forest decision trees boosting techniques cluster analysis word embedding sentiment analysis natural language processing dimensionality reduction topic modelling lda nmf pca neural nets database visualizations mysql sqlserver cassandra hbase elasticsearch d3 js dc js plotly kibana matplotlib ggplot tableau others regular expression html css angular 6 logstash kafka python flask git docker computer vision open cv and understanding of deep learning education details data science assurance associate data science assurance associate ernst young llp skill details javascript exprience 24 months jquery exprience 24 months python exprience 24 monthscompany details company ernst young llp description fraud investigations and dispute services assurance technology assisted review tar technology assisted review assists in a elerating th
# ...

# %% [markdown]
# ##**Loading the en_core_web_sm model, which is a small, pre-trained spaCy language model for English. It includes tokenization, lemmatization, named entity recognition (NER), and part-of-speech (POS) tagging.**

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def clean_resume_advanced(text):
    doc = nlp(text)
    return " ".join([token.lemma_ for token in doc if not token.is_stop and token.is_alpha])

df["Resume"] = df["Resume"].apply(clean_resume_advanced)

# %%
df["Resume"][0]
# Out:
# 'skill programming language python pandas numpy scipy scikit learn matplotlib sql java javascript jquery machine learn regression svm na ve baye knn random forest decision tree boost technique cluster analysis word embed sentiment analysis natural language process dimensionality reduction topic model lda nmf pca neural net database visualization mysql sqlserver cassandra hbase elasticsearch js dc js plotly kibana matplotlib ggplot tableau regular expression html css angular logstash kafka python flask git docker computer vision open cv understanding deep learn education detail datum science assurance associate datum science assurance associate ernst young llp skill detail javascript exprience month jquery exprience month python exprience monthscompany detail company ernst young llp description fraud investigation dispute service assurance technology assist review tar technology assist review assist elerate review process run analytic generate report core member team help develop auto
# ...

# %% [markdown]
# ##**Changing the Words into "Categorical Values"**

# %% [markdown]
# ##**Here we are going train our data i.e first we fit our data and then transform the data(Where our words will convert into text) with the help of label encoding.**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(df["Category"])
df["Category"] = le.transform(df["Category"])

# %%
df
# Out:
#      Category                                             Resume
# 0           6  skill programming language python pandas numpy...
# 1           6  education detail b e uit rgpv data scientist d...
# 2           6  area interest deep learn control system design...
# 3           6  skill r python sap hana tableau sap hana sql s...
# 4           6  education detail mca ymcaust faridabad haryana...
# ..        ...                                                ...
# 957        23  computer skill proficient ms office word basic...
# 958        23  willingness ept challenge positive thinking go...
# 959        23  personal skill quick learner eagerness learn n...
# 960        23  computer skill software knowledge ms power poi...
# 961        23  skill set os windows xp database mysql sql ser...
#
# [962 rows x 2 columns]

# %%
#Checking the unique vectors assigned to the categories.
df["Category"].unique()
# Out:
# array([ 6, 12,  0,  1, 24, 16, 22, 14,  5, 15,  4, 21,  2, 11, 18, 20,  8,
#        17, 19,  7, 13, 10,  9,  3, 23])

# %%
#        Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing',
#      'Civil Engineer', 'Java Developer', 'Business Analyst',
#      'SAP Developer', 'Automation Testing', 'Electrical Engineering',
#      'Operations Manager', 'Python Developer', 'DevOps Engineer',
#      'Network Security Engineer', 'PMO', 'Database', 'Hadoop',
#     'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing

# %% [markdown]
# ##**Vectorization of the Resume column by using TF-IDF(Term Frequency-Inverse Document Frequency.**
#
# ###**Why are we using it?**
#
# ###**->TF-IDF (Term Frequency-Inverse Document Frequency) is a statistical measure used in natural language processing and information retrieval to evaluate the importance of a word in a document relative to a collection of documents (corpus).**
#
# ###**In natural language processing (NLP), TF-IDF is often used to convert text data into numerical features for machine learning models.**

# %% [markdown]
# ##**Spliting the data for train data and test data.**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
# Add bigrams or trigrams to capture context
tfidf = TfidfVectorizer(stop_words="english", ngram_range=(1, 2))
required_text = tfidf.fit_transform(df["Resume"])


# Initialize TF-IDF Vectorizer
tfidf = TfidfVectorizer(max_features=3000, stop_words='english')

# Transform the cleaned resume text
required_text = tfidf.fit_transform(df['Resume']).toarray()

# Target variable (Category)
df['Category']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(required_text, df["Category"], test_size=0.2, random_state=42)

# %%
df
# Out:
#      Category                                             Resume
# 0           6  skill programming language python pandas numpy...
# 1           6  education detail b e uit rgpv data scientist d...
# 2           6  area interest deep learn control system design...
# 3           6  skill r python sap hana tableau sap hana sql s...
# 4           6  education detail mca ymcaust faridabad haryana...
# ..        ...                                                ...
# 957        23  computer skill proficient ms office word basic...
# 958        23  willingness ept challenge positive thinking go...
# 959        23  personal skill quick learner eagerness learn n...
# 960        23  computer skill software knowledge ms power poi...
# 961        23  skill set os windows xp database mysql sql ser...
#
# [962 rows x 2 columns]

# %%
X_train.shape
# Out:
# (769, 3000)

# %%
X_test.shape
# Out:
# (193, 3000)

# %% [markdown]
# ##**Training the model and printing classification report.**

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
clf = MultinomialNB()        #created a classifier to store the instance of Multinomial Naive Bayes
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)
print(ypred)
print()
print(accuracy_score(y_test,ypred))
# Out:
# [15 15 15 13 14 17 16  2  0 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23  6 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8  0  2  9 10  2 23 20 20
#  23 15 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23  5
#  11 15 12  3  5  3  7 12 19  8 20 19  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11  5 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20  6  6  7
#  23]
#
# 0.9896373056994818

# %% [markdown]
# ###**A Logistic Regression model using scikit-learn with a specified maximum of 1000 iterations and a fixed random state for reproducibility. It evaluates the model's performance on a test dataset by generating predictions and calculating metrics such as a classification report, accuracy score, and confusion matrix.**

# %% [markdown]
# ##**Training and evaluating a Logistic Regression model for a classification task:**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Initialize and train the Logistic Regression model
model = LogisticRegression(max_iter=1000, random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model's performance
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         8
#            8       1.00      0.93      0.96        14
#            9       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         6
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         7
#           15       1.00      1.00      1.00        15
# ...

# %% [markdown]
# ##**Building a prediction system.**

# %%
# Make predictions for new resumes
new_resumes = [
    "Expert in Python, machine learning, and data analysis.",
    "Experienced in designing and developing Java applications.",
    "Specialist in digital marketing and social media management."
]
new_features = tfidf.transform(new_resumes)  # Transform new resumes using the fitted TF-IDF Vectorizer
predictions = model.predict(new_features)

# Display predictions
for resume, category in zip(new_resumes, predictions):
    print(f"Resume: {resume}")
    print(f"Predicted Category: {category}")
    print()
# Out:
# Resume: Expert in Python, machine learning, and data analysis.
# Predicted Category: 6
#
# Resume: Experienced in designing and developing Java applications.
# Predicted Category: 15
#
# Resume: Specialist in digital marketing and social media management.
# Predicted Category: 1
